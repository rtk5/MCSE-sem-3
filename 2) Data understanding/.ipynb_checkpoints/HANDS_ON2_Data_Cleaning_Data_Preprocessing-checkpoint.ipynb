# %%
import pandas as pd

# Replace 'YourUsername' with your actual system username
file_path = 'C:/Users/Shruti/Downloads/archive/Titanic_modified - 1.csv'

# Load the Titanic dataset
df = pd.read_csv(file_path)

# %%
df.describe(include="all")
# Out:
#         PassengerId       Pclass     Name   Sex         Age        SibSp  \
# count   1060.000000  1060.000000     1060  1060  956.000000  1060.000000
# unique          NaN          NaN     1006     2         NaN          NaN
# top             NaN          NaN  Outlier  male         NaN          NaN
# freq            NaN          NaN        9   561         NaN          NaN
# mean     505.923585     1.962264      NaN   NaN   38.956683     2.024528
# std      290.917806     0.819089      NaN   NaN   23.207335     1.427956
# min        1.000000     1.000000      NaN   NaN    1.000000     0.000000
# 25%      256.750000     1.000000      NaN   NaN   19.000000     1.000000
# 50%      503.500000     2.000000      NaN   NaN   37.000000     2.000000
# 75%      757.250000     3.000000      NaN   NaN   60.000000     3.000000
# max     1010.000000     3.000000      NaN   NaN   93.785790     4.000000
#
#               Parch Ticket         Fare Embarked     Survived Cabin  Luggage
# count   1060.000000   1060  1060.000000      955  1060.000000    10      0.0
# unique          NaN   1001          NaN        4          NaN     1      NaN
# top             NaN    XXX          NaN        Q          NaN     Z      NaN
# freq            NaN     10          NaN      323          NaN    10      NaN
# mean       2.013208    NaN   253.106194      NaN     0.497170   NaN      NaN
# std        1.416820    NaN   146.099277      NaN     0.500228   NaN      NaN
# min        0.000000    NaN    10.020000      NaN     0.000000   NaN      NaN
# 25%        1.000000    NaN   129.835000      NaN     0.000000   NaN      NaN
# 50%        2.000000    NaN   249.505000      NaN     0.000000   NaN      NaN
# 75%        3.000000    NaN   368.130000      NaN     1.000000   NaN      NaN
# max        4.000000    NaN   877.729485      NaN     1.000000   NaN      NaN

# %%
# Check for missing values
missing_counts = df.isnull().sum()
missing_rows = df.isnull().sum(axis=1)

# %%
# Check for columns that are completely empty
empty_columns = missing_counts[missing_counts == len(df)].index
print("\nColumns that are completely empty:")
print(empty_columns)
# Out:
# Columns that are completely empty:
# Index(['Luggage'], dtype='object')

# %%
# Display the number of rows with missing values
print("\nNumber of missing values per row:")
print(missing_rows.value_counts())
# Out:
# Number of missing values per row:
# 2    851
# 3    189
# 4     10
# 1     10
# Name: count, dtype: int64

# %%
# Display the number of missing values in each column
print("Missing values per column:")
print(missing_counts)
# Out:
# Missing values per column:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age             104
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Embarked        105
# Survived          0
# Cabin          1050
# Luggage        1060
# dtype: int64

# %% [raw]
# Decide whether to drop or impute based on the number of missing values

# %%
# Drop columns that are completely empty
df_cleaned = df.drop(columns=empty_columns)

# %%
print("\nColumns dropped due to being completely empty:")
print(empty_columns)
# Out:
# Columns dropped due to being completely empty:
# Index(['Luggage'], dtype='object')

# %%
print("\nDataFrame after dropping empty columns:")
df_cleaned.describe(include='all')
# Out:
# DataFrame after dropping empty columns:
#         PassengerId       Pclass     Name   Sex         Age        SibSp  \
# count   1060.000000  1060.000000     1060  1060  956.000000  1060.000000
# unique          NaN          NaN     1006     2         NaN          NaN
# top             NaN          NaN  Outlier  male         NaN          NaN
# freq            NaN          NaN        9   561         NaN          NaN
# mean     505.923585     1.962264      NaN   NaN   38.956683     2.024528
# std      290.917806     0.819089      NaN   NaN   23.207335     1.427956
# min        1.000000     1.000000      NaN   NaN    1.000000     0.000000
# 25%      256.750000     1.000000      NaN   NaN   19.000000     1.000000
# 50%      503.500000     2.000000      NaN   NaN   37.000000     2.000000
# 75%      757.250000     3.000000      NaN   NaN   60.000000     3.000000
# max     1010.000000     3.000000      NaN   NaN   93.785790     4.000000
#
#               Parch Ticket         Fare Embarked     Survived Cabin
# count   1060.000000   1060  1060.000000      955  1060.000000    10
# unique          NaN   1001          NaN        4          NaN     1
# top             NaN    XXX          NaN        Q          NaN     Z
# freq            NaN     10          NaN      323          NaN    10
# mean       2.013208    NaN   253.106194      NaN     0.497170   NaN
# std        1.416820    NaN   146.099277      NaN     0.500228   NaN
# min        0.000000    NaN    10.020000      NaN     0.000000   NaN
# 25%        1.000000    NaN   129.835000      NaN     0.000000   NaN
# 50%        2.000000    NaN   249.505000      NaN     0.000000   NaN
# 75%        3.000000    NaN   368.130000      NaN     1.000000   NaN
# max        4.000000    NaN   877.729485      NaN     1.000000   NaN

# %%
# Work with cleaned DataFrame
df_imputed = df_cleaned.copy()

# %%
# Impute missing values for non-empty columns
for column in df_imputed.columns:
    if df_imputed[column].isnull().sum() > 0:
        if df_imputed[column].dtype == 'object':
            # Impute with mode for categorical columns
            mode_value = df_imputed[column].mode().iloc[0]
            df_imputed[column] = df_imputed[column].fillna(mode_value)
        else:
            # Impute with mean for numerical columns
            mean_value = df_imputed[column].mean()
            df_imputed[column] = df_imputed[column].fillna(mean_value)

# %%
print("\nDataFrame after imputing missing values:")
df_imputed.describe(include='all')
# Out:
# DataFrame after imputing missing values:
#         PassengerId       Pclass     Name   Sex          Age        SibSp  \
# count   1060.000000  1060.000000     1060  1060  1060.000000  1060.000000
# unique          NaN          NaN     1006     2          NaN          NaN
# top             NaN          NaN  Outlier  male          NaN          NaN
# freq            NaN          NaN        9   561          NaN          NaN
# mean     505.923585     1.962264      NaN   NaN    38.956683     2.024528
# std      290.917806     0.819089      NaN   NaN    22.038345     1.427956
# min        1.000000     1.000000      NaN   NaN     1.000000     0.000000
# 25%      256.750000     1.000000      NaN   NaN    21.000000     1.000000
# 50%      503.500000     2.000000      NaN   NaN    38.956683     2.000000
# 75%      757.250000     3.000000      NaN   NaN    57.000000     3.000000
# max     1010.000000     3.000000      NaN   NaN    93.785790     4.000000
#
#               Parch Ticket         Fare Embarked     Survived Cabin
# count   1060.000000   1060  1060.000000     1060  1060.000000  1060
# unique          NaN   1001          NaN        4          NaN     1
# top             NaN    XXX          NaN        Q          NaN     Z
# freq            NaN     10          NaN      428          NaN  1060
# mean       2.013208    NaN   253.106194      NaN     0.497170   NaN
# std        1.416820    NaN   146.099277      NaN     0.500228   NaN
# min        0.000000    NaN    10.020000      NaN     0.000000   NaN
# 25%        1.000000    NaN   129.835000      NaN     0.000000   NaN
# 50%        2.000000    NaN   249.505000      NaN     0.000000   NaN
# 75%        3.000000    NaN   368.130000      NaN     1.000000   NaN
# max        4.000000    NaN   877.729485      NaN     1.000000   NaN

# %%
# Identify duplicate rows
print("\nDuplicate rows:")
df_imputed[df_imputed.duplicated(keep='first')]
# Out:
# Duplicate rows:
#       PassengerId  Pclass                  Name     Sex        Age  SibSp  \
# 1001          326       2         Patrick Moore  female  57.000000      2
# 1002          746       3         Vincent Novak    male  63.000000      1
# 1003          362       3        Laurie Hoffman  female  14.000000      4
# 1004          627       3            Amy Kelley    male  22.000000      3
# 1007            9       3       Gabrielle Davis    male  63.000000      4
# 1008          305       1          Maria Parker    male  78.000000      0
# 1009          716       2       David Davenport    male  52.000000      0
# 1010          405       2           Joann Glass    male  74.000000      2
# 1011          864       3      Tiffany Townsend  female  13.000000      3
# 1013          347       1           Sharon Boyd  female  43.000000      3
# 1014          298       2       William Barrett    male  44.000000      1
# 1015          989       1          Anna Wheeler  female  15.000000      0
# 1016          146       3           Joyce Solis    male  38.956683      1
# 1017          894       2          Cassie Brock    male  29.000000      3
# 1018          887       1       Jordan Williams  female  37.000000      1
# 1020          117       1       William Herrera    male  72.000000      2
# 1021          313       3        Shannon Ramsey  female  35.000000      3
# 1022          519       1          Penny Bowman    male  11.000000      4
# 1024          949       1          Robert Stark    male   4.000000      0
# 1025          811       1          Carol Taylor  female   5.000000      3
# 1027          975       1         Taylor Taylor    male  55.000000      3
# 1028          501       2        Jennifer Banks  female  74.000000      2
# 1029          113       1          Julia Torres  female  48.000000      0
# 1030          476       1       Julie Dominguez    male  54.000000      1
# 1031          602       3  Jennifer Simpson DVM  female  70.000000      4
# 1033          531       3          Marilyn Wang  female  67.000000      2
# 1034          718       1         Brenda Hinton  female  38.000000      2
# 1035          765       1           Jorge Stone    male   1.000000      4
# 1036          711       2         Anthony Jones    male   4.000000      4
# 1037          237       2       Andrew Reynolds  female  38.956683      0
# 1039          322       3          Charles Shah  female  38.956683      3
# 1040          664       2         Samuel Turner    male  52.000000      1
# 1042          903       2          Sherry Tapia    male   5.000000      4
# 1043          739       2      Mr. David Wright    male  13.000000      3
# 1044          972       1          Jenna Gamble    male  19.000000      3
# 1046          105       3        Richard Henson  female  46.000000      0
# 1047          413       2         Julian Conner    male  66.000000      2
# 1048          357       1           Jesse Perry    male  68.000000      3
# 1049          364       2        Nicole Parrish  female  48.000000      3
#
#       Parch                                Ticket    Fare Embarked  Survived  \
# 1001      2  597278c5-1789-4e63-a746-5743897b303d  368.43        S         0
# 1002      4  e3f342a8-f030-4fd4-be54-898e8eda6433  470.39        C         1
# 1003      1  d926fe41-b36d-4121-8ba6-fe0995ea6825  179.44        Q         1
# 1004      0  bfeef19d-b360-4faa-be6e-9d47f0c0804b  344.27        Q         1
# 1007      1  69fb0763-8a9c-46f7-8ee4-e5125802b640  234.63        C         1
# 1008      4  716ca1f2-dec0-4f3a-9c46-1b34c7eab19b  409.19        S         0
# 1009      3  8f1c3fa0-7000-4009-b4e5-70ba7c3cc2bc  477.74        Q         0
# 1010      4  47d6723c-d77f-4eeb-94fc-3a5d9b4bf377  291.24        S         1
# 1011      4  afbffde4-a022-4155-9f69-5d179cc96aed   96.77        Q         0
# 1013      1  af76b6c2-dd6d-4b41-b692-a531c6097cd8  458.38        Q         0
# 1014      2  cbfd4a31-c8c8-4ad6-82cb-cdc73cd30e99  469.86        C         0
# 1015      3  1d2467e2-0191-419d-845c-3fbb52ecac27  206.15        S         1
# 1016      4  10b6a662-2ac1-45ca-8e5d-8f1296b31f4a  342.46        C         1
# 1017      1  f80443ee-c3b8-4179-a899-4c8408403234  368.13        S         0
# 1018      3  3b1d12cf-3b70-4092-98ab-182c3b1d0181  120.08        C         1
# 1020      4  e3082ddc-c9c0-4b7d-aba4-170b4e9d23e9  365.05        S         1
# 1021      2  0a670143-6090-403c-9e8d-f8ad838b77ad  332.50        Q         0
# 1022      4  2cde9187-d1fa-42a6-860b-340cf21a6f38  344.44        Q         1
# 1024      4  a0ee404f-9ea8-4cb1-8732-68c98c1e9464  253.16        C         0
# 1025      2  65339cf0-7ce4-470e-b2b7-3d808f2e08d3   49.25        S         1
# 1027      3  ed56c714-5a96-41f5-9f8c-eda5feb9ea24  141.71        Q         0
# 1028      2  7bd7b4bf-8e0e-4bb7-8f20-c5e75ec646eb  411.01        S         0
# 1029      0  e9a1c6d5-c34e-4baf-8f1c-b2ccceef9fa8   22.24        S         1
# 1030      0  a8cdf44d-7b74-4440-97db-4c2f1e158e2f  142.62        Q         1
# 1031      0  18a73d94-a13e-466d-96c6-d99779fe7ccc  427.06        S         1
# 1033      1  8cb21aa2-1715-4c03-ab4f-36381190e515   74.18        C         1
# 1034      3  8b2ab759-2fc6-44e6-9113-5d7e30952621  243.93        Q         0
# 1035      4  698f546d-5f29-4290-9848-5a54531c8812  294.52        C         1
# 1036      4  a50784cb-c9df-401e-8ef0-0de1fb4f1972  327.63        S         1
# 1037      1  a7939a2e-34f4-4404-8ff5-070182226c16  301.48        S         1
# 1039      0  b52a9e6b-c8b6-48e0-92a8-50c55bab7f4a  440.87        C         0
# 1040      4  b1a50a3d-cebd-4b2b-9cfb-bce7e8f2c584  133.63        Q         1
# 1042      1  b85f164b-6160-4399-9307-3198bc3eb402  213.75        Q         1
# 1043      1  9fbc879e-869c-4a8e-bd6a-b7c2a86d8706  204.19        C         0
# 1044      1  b4f136fc-fc7c-4e71-89c6-7b51ef13864b  457.39        Q         0
# 1046      3  57d9cbb0-309e-47ba-90e6-56e592715f6e  259.83        C         0
# 1047      2  e4dc4306-8b20-4e3e-82b7-c0488d3543be  298.29        C         0
# 1048      2  737cf8b5-6356-4add-a85a-9f2b4236c0bf   13.13        Q         1
# 1049      0  af95be79-c971-4f51-8a32-bb221b2bb2ec  404.66        S         0
#
#      Cabin
# 1001     Z
# 1002     Z
# 1003     Z
# 1004     Z
# 1007     Z
# 1008     Z
# 1009     Z
# 1010     Z
# 1011     Z
# 1013     Z
# 1014     Z
# 1015     Z
# 1016     Z
# 1017     Z
# 1018     Z
# 1020     Z
# 1021     Z
# 1022     Z
# 1024     Z
# 1025     Z
# 1027     Z
# 1028     Z
# 1029     Z
# 1030     Z
# 1031     Z
# 1033     Z
# 1034     Z
# 1035     Z
# 1036     Z
# 1037     Z
# 1039     Z
# 1040     Z
# 1042     Z
# 1043     Z
# 1044     Z
# 1046     Z
# 1047     Z
# 1048     Z
# 1049     Z

# %%
# Handle duplicates
df_final = df_imputed.drop_duplicates()

# %%
print("\nNumber of duplicate rows removed:")
print(len(df_imputed) - len(df_final))
# Out:
# Number of duplicate rows removed:
# 39

# %%
print("\nDataFrame after removing duplicates:")
df_final.describe(include='all')
# Out:
# DataFrame after removing duplicates:
#         PassengerId       Pclass     Name   Sex          Age        SibSp  \
# count   1021.000000  1021.000000     1021  1021  1021.000000  1021.000000
# unique          NaN          NaN     1006     2          NaN          NaN
# top             NaN          NaN  Outlier  male          NaN          NaN
# freq            NaN          NaN        9   539          NaN          NaN
# mean     504.584721     1.964740      NaN   NaN    38.901287     2.019589
# std      291.232688     0.819332      NaN   NaN    21.986210     1.429935
# min        1.000000     1.000000      NaN   NaN     1.000000     0.000000
# 25%      253.000000     1.000000      NaN   NaN    21.000000     1.000000
# 50%      503.000000     2.000000      NaN   NaN    38.956683     2.000000
# 75%      757.000000     3.000000      NaN   NaN    57.000000     3.000000
# max     1010.000000     3.000000      NaN   NaN    93.785790     4.000000
#
#               Parch Ticket         Fare Embarked     Survived Cabin
# count   1021.000000   1021  1021.000000     1021  1021.000000  1021
# unique          NaN   1001          NaN        4          NaN     1
# top             NaN    XXX          NaN        Q          NaN     Z
# freq            NaN     10          NaN      414          NaN  1021
# mean       2.006856    NaN   252.006744      NaN     0.495593   NaN
# std        1.415236    NaN   146.448740      NaN     0.500226   NaN
# min        0.000000    NaN    10.020000      NaN     0.000000   NaN
# 25%        1.000000    NaN   126.690000      NaN     0.000000   NaN
# 50%        2.000000    NaN   247.170000      NaN     0.000000   NaN
# 75%        3.000000    NaN   367.810000      NaN     1.000000   NaN
# max        4.000000    NaN   877.729485      NaN     1.000000   NaN

# %%
# Handle outliers

# Function to identify outliers in a column
def identify_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

# %%
# Identify and display potential outliers for each numerical column
for column in df_final.select_dtypes(include=['float64', 'int64']).columns:
    outliers = identify_outliers(df_final, column)
    if not outliers.empty:
        print(f"\nPotential outliers in column '{column}':")
        print(outliers[[column]])
# Out:
# Potential outliers in column 'Fare':
#             Fare
# 1050  793.392633
# 1052  808.643393
# 1053  857.163810
# 1057  877.729485

# %%
# Remove outliers
df_no_outliers = df_final.copy()  # Work with DataFrame after removing duplicates

for column in df_no_outliers.select_dtypes(include=['float64', 'int64']).columns:
    Q1 = df_no_outliers[column].quantile(0.25)
    Q3 = df_no_outliers[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_no_outliers = df_no_outliers[(df_no_outliers[column] >= lower_bound) & (df_no_outliers[column] <= upper_bound)]

# %%
print("\nNumber of rows before and after outlier removal:")
print("Before:", len(df_final))
print("After:", len(df_no_outliers))
# Out:
# Number of rows before and after outlier removal:
# Before: 1021
# After: 1017

# %%
print("\nDataFrame after handling outliers:")
df_no_outliers.describe(include='all')
# Out:
# DataFrame after handling outliers:
#         PassengerId       Pclass     Name   Sex          Age        SibSp  \
# count   1017.000000  1017.000000     1017  1017  1017.000000  1017.000000
# unique          NaN          NaN     1006     2          NaN          NaN
# top             NaN          NaN  Outlier  male          NaN          NaN
# freq            NaN          NaN        5   537          NaN          NaN
# mean     502.620452     1.965585      NaN   NaN    38.885593     2.026549
# std      290.111293     0.820382      NaN   NaN    22.017938     1.428163
# min        1.000000     1.000000      NaN   NaN     1.000000     0.000000
# 25%      252.000000     1.000000      NaN   NaN    21.000000     1.000000
# 50%      501.000000     2.000000      NaN   NaN    38.956683     2.000000
# 75%      754.000000     3.000000      NaN   NaN    57.000000     3.000000
# max     1010.000000     3.000000      NaN   NaN    93.785790     4.000000
#
#               Parch Ticket         Fare Embarked     Survived Cabin
# count   1017.000000   1017  1017.000000     1017  1017.000000  1017
# unique          NaN   1001          NaN        4          NaN     1
# top             NaN    XXX          NaN        Q          NaN     Z
# freq            NaN      6          NaN      413          NaN  1017
# mean       2.001967    NaN   249.716771      NaN     0.496559   NaN
# std        1.413516    NaN   142.081537      NaN     0.500234   NaN
# min        0.000000    NaN    10.020000      NaN     0.000000   NaN
# 25%        1.000000    NaN   126.360000      NaN     0.000000   NaN
# 50%        2.000000    NaN   246.810000      NaN     0.000000   NaN
# 75%        3.000000    NaN   367.040000      NaN     1.000000   NaN
# max        4.000000    NaN   697.298995      NaN     1.000000   NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Box plot before removing outliers
plt.figure(figsize=(12, 6))
sns.boxplot(x=df_imputed['Fare'])
plt.title('Box Plot of Fare Before Removing Outliers')
plt.xlabel('Fare')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Box plot after removing outliers
plt.figure(figsize=(12, 6))
sns.boxplot(x=df_no_outliers['Fare'])
plt.title('Box Plot of Fare After Removing Outliers')
plt.xlabel('Fare')
plt.show()

# %%
df_no_outliers.describe()
# Out:
#        PassengerId       Pclass          Age        SibSp        Parch  \
# count  1017.000000  1017.000000  1017.000000  1017.000000  1017.000000
# mean    502.620452     1.965585    38.885593     2.026549     2.001967
# std     290.111293     0.820382    22.017938     1.428163     1.413516
# min       1.000000     1.000000     1.000000     0.000000     0.000000
# 25%     252.000000     1.000000    21.000000     1.000000     1.000000
# 50%     501.000000     2.000000    38.956683     2.000000     2.000000
# 75%     754.000000     3.000000    57.000000     3.000000     3.000000
# max    1010.000000     3.000000    93.785790     4.000000     4.000000
#
#               Fare     Survived
# count  1017.000000  1017.000000
# mean    249.716771     0.496559
# std     142.081537     0.500234
# min      10.020000     0.000000
# 25%     126.360000     0.000000
# 50%     246.810000     0.000000
# 75%     367.040000     1.000000
# max     697.298995     1.000000

# %%
from sklearn.preprocessing import StandardScaler
# Standardization (z-score normalization)
scaler = StandardScaler()
df_standardized = df_no_outliers.copy()

# Apply standardization to numerical columns
numerical_columns = df_standardized.select_dtypes(include=['float64', 'int64']).columns
df_standardized[numerical_columns] = scaler.fit_transform(df_standardized[numerical_columns])

# %%
# Display the standardized DataFrame
print("\nDataFrame after standardization:")
df_standardized.describe()
# Out:
# DataFrame after standardization:
#         PassengerId        Pclass          Age         SibSp         Parch  \
# count  1.017000e+03  1.017000e+03  1017.000000  1.017000e+03  1.017000e+03
# mean   1.117865e-16  1.397331e-17     0.000000  1.379864e-16  4.191993e-17
# std    1.000492e+00  1.000492e+00     1.000492  1.000492e+00  1.000492e+00
# min   -1.729913e+00 -1.177573e+00    -1.721516 -1.419688e+00 -1.417000e+00
# 25%   -8.643020e-01 -1.177573e+00    -0.812719 -7.191434e-01 -7.091957e-01
# 50%   -5.588371e-03  4.197053e-02     0.003230 -1.859853e-02 -1.391945e-03
# 75%    8.669198e-01  1.261514e+00     0.823116  6.819463e-01  7.064118e-01
# max    1.749774e+00  1.261514e+00     2.494657  1.382491e+00  1.414216e+00
#
#                Fare      Survived
# count  1.017000e+03  1.017000e+03
# mean   8.907984e-17 -1.222664e-16
# std    1.000492e+00  1.000492e+00
# min   -1.687867e+00 -9.931405e-01
# 25%   -8.686383e-01 -9.931405e-01
# 50%   -2.046853e-02 -9.931405e-01
# 75%    8.261520e-01  1.006907e+00
# max    3.151729e+00  1.006907e+00

# %%
df_standardized.head()
# Out:
#    PassengerId    Pclass             Name     Sex       Age     SibSp  \
# 0    -1.729913  1.261514     Allison Hill    male -0.994478  1.382491
# 1    -1.726464 -1.177573      Noah Rhodes    male  0.959436 -0.018599
# 2    -1.723016  1.261514  Angie Henderson    male  1.141195 -1.419688
# 3    -1.719567  1.261514    Daniel Wagner    male -0.176561  1.382491
# 4    -1.716118 -1.177573  CRISTIAN SANTOS  female  1.413834 -1.419688
#
#       Parch                                Ticket      Fare Embarked  \
# 0 -0.001392  43d75413-a939-4bd1-a516-b0d47d3572cc -0.743860        Q
# 1 -0.001392  6334fa2a-8b4b-47e7-a451-5ae01754bf08 -0.004766        X
# 2 -1.417000  61a66444-e2af-4629-9efb-336e2f546033 -1.404158        X
# 3 -1.417000  0b6c03c8-721e-4419-afc3-e6495e911b91 -0.102222        C
# 4  0.706412  436e3c49-770e-49db-b092-d40143675d58 -0.630559        Q
#
#    Survived Cabin
# 0  1.006907     Z
# 1 -0.993141     Z
# 2  1.006907     Z
# 3  1.006907     Z
# 4  1.006907     Z

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalization (min-max scaling)
normalizer = MinMaxScaler()
df_normalized = df_no_outliers.copy()

# Apply normalization to numerical columns
df_normalized[numerical_columns] = normalizer.fit_transform(df_normalized[numerical_columns])

# %%
# Display the normalized DataFrame
print("\nDataFrame after normalization:")
df_normalized.describe(include='all')
# Out:
# DataFrame after normalization:
#         PassengerId       Pclass     Name   Sex          Age        SibSp  \
# count   1017.000000  1017.000000     1017  1017  1017.000000  1017.000000
# unique          NaN          NaN     1006     2          NaN          NaN
# top             NaN          NaN  Outlier  male          NaN          NaN
# freq            NaN          NaN        5   537          NaN          NaN
# mean       0.497146     0.482793      NaN   NaN     0.408312     0.506637
# std        0.287524     0.410191      NaN   NaN     0.237299     0.357041
# min        0.000000     0.000000      NaN   NaN     0.000000     0.000000
# 25%        0.248761     0.000000      NaN   NaN     0.215550     0.250000
# 50%        0.495540     0.500000      NaN   NaN     0.409079     0.500000
# 75%        0.746283     1.000000      NaN   NaN     0.603541     0.750000
# max        1.000000     1.000000      NaN   NaN     1.000000     1.000000
#
#               Parch Ticket         Fare Embarked     Survived Cabin
# count   1017.000000   1017  1017.000000     1017  1017.000000  1017
# unique          NaN   1001          NaN        4          NaN     1
# top             NaN    XXX          NaN        Q          NaN     Z
# freq            NaN      6          NaN      413          NaN  1017
# mean       0.500492    NaN     0.348762      NaN     0.496559   NaN
# std        0.353379    NaN     0.206731      NaN     0.500234   NaN
# min        0.000000    NaN     0.000000      NaN     0.000000   NaN
# 25%        0.250000    NaN     0.169276      NaN     0.000000   NaN
# 50%        0.500000    NaN     0.344533      NaN     0.000000   NaN
# 75%        0.750000    NaN     0.519469      NaN     1.000000   NaN
# max        1.000000    NaN     1.000000      NaN     1.000000   NaN

# %%
import matplotlib.pyplot as plt

# Plot histograms for numerical columns
def plot_histograms(df, title):
    df.hist(bins=30, figsize=(14, 10))
    plt.suptitle(title)
    plt.show()

plot_histograms(df_no_outliers, 'Histograms Before Standardization and Normalization')
plot_histograms(df_standardized, 'Histograms After Standardization')
plot_histograms(df_normalized, 'Histograms After Normalization')

# %%
# Identify the current data types
print("Data types before conversion:")
df_standardized.dtypes
# Out:
# Data types before conversion:
# PassengerId    float64
# Pclass         float64
# Name            object
# Sex              int32
# Age            float64
# SibSp          float64
# Parch          float64
# Ticket          object
# Fare           float64
# Embarked         int32
# Survived       float64
# Cabin            int32
# dtype: object

# %%
# Convert any date columns to datetime (if applicable)
# Replace 'date_column' with actual date column name if applicable
if 'date_column' in df_standardized.columns:
    df_standardized['date_column'] = pd.to_datetime(df_standardized['date_column'], errors='coerce')

# %%
# Convert categorical columns to 'category' data type
# Assuming 'Sex', 'Embarked', and 'Cabin' are categorical columns
categorical_columns = ['Sex', 'Embarked', 'Cabin']
for column in categorical_columns:
    if column in df_standardized.columns:
        df_standardized[column] = df_standardized[column].astype('category')

# %%
# Convert numerical columns that might have been converted to objects back to numeric
for column in df_standardized.select_dtypes(include=['object']).columns:
    df_standardized[column] = pd.to_numeric(df_standardized[column], errors='coerce')

# %%
# Verify the data types after conversion
print("\nData types after conversion:")
df_standardized.dtypes
# Out:
# Data types after conversion:
# PassengerId     float64
# Pclass          float64
# Name            float64
# Sex            category
# Age             float64
# SibSp           float64
# Parch           float64
# Ticket          float64
# Fare            float64
# Embarked       category
# Survived        float64
# Cabin          category
# dtype: object

# %%
print("Before Text Normalization:")
df_standardized[['Name', 'Ticket']].head()
# Out:
# Before Text Normalization:
#               Name                                Ticket
# 0     Allison Hill  43d75413-a939-4bd1-a516-b0d47d3572cc
# 1      Noah Rhodes  6334fa2a-8b4b-47e7-a451-5ae01754bf08
# 2  Angie Henderson  61a66444-e2af-4629-9efb-336e2f546033
# 3    Daniel Wagner  0b6c03c8-721e-4419-afc3-e6495e911b91
# 4  CRISTIAN SANTOS  436e3c49-770e-49db-b092-d40143675d58

# %%
# Text Normalization: Strip leading/trailing spaces and convert to lowercase for textual columns
# Ensure the 'Name' and 'Ticket' columns are converted to strings before applying text normalization
df_standardized['Name'] = df_standardized['Name'].astype(str).str.strip().str.lower()
df_standardized['Ticket'] = df_standardized['Ticket'].astype(str).str.strip().str.lower()

# %%
# Verify changes
print("\nText Normalization for 'Name' and 'Ticket':")
df_standardized[['Name', 'Ticket']].head()
# Out:
# Text Normalization for 'Name' and 'Ticket':
#               Name                                Ticket
# 0     allison hill  43d75413-a939-4bd1-a516-b0d47d3572cc
# 1      noah rhodes  6334fa2a-8b4b-47e7-a451-5ae01754bf08
# 2  angie henderson  61a66444-e2af-4629-9efb-336e2f546033
# 3    daniel wagner  0b6c03c8-721e-4419-afc3-e6495e911b91
# 4  cristian santos  436e3c49-770e-49db-b092-d40143675d58

# %%
# Display original values of 'Sex', 'Embarked', and 'Cabin' columns before encoding
print("Before Encoding:")
df_standardized[['Sex', 'Embarked', 'Cabin']].head()
# Out:
# Before Encoding:
#       Sex Embarked Cabin
# 0    male        Q     Z
# 1    male        X     Z
# 2    male        X     Z
# 3    male        C     Z
# 4  female        Q     Z

# %%
# Apply One-Hot Encoding for 'Sex', 'Embarked', and 'Cabin' columns
df_one_hot_encoded = pd.get_dummies(df_standardized, columns=['Sex', 'Embarked', 'Cabin'], drop_first=True)

# Identify new columns added by One-Hot Encoding
new_columns = [col for col in df_one_hot_encoded.columns if col not in df_standardized.columns]

# Display the new columns and their content
print("\nNew Columns after One-Hot Encoding and their content:")
df_one_hot_encoded[new_columns].head()
# Out:
# New Columns after One-Hot Encoding and their content:
#    Sex_male  Embarked_Q  Embarked_S  Embarked_X
# 0      True        True       False       False
# 1      True       False       False        True
# 2      True       False       False        True
# 3      True       False       False       False
# 4     False        True       False       False

# %%
from sklearn.preprocessing import LabelEncoder

# Apply Label Encoding for 'Sex', 'Embarked', and 'Cabin' columns
label_encoders = {}
for column in categorical_columns:
    if column in df_standardized.columns:
        le = LabelEncoder()
        df_standardized[column] = le.fit_transform(df_standardized[column].astype(str))
        label_encoders[column] = le  # Save label encoders for potential use later

# Display the columns after encoding
print("\nAfter Label Encoding:")
df_standardized[categorical_columns].head()
# Out:
# After Label Encoding:
#    Sex  Embarked  Cabin
# 0    1         1      0
# 1    1         3      0
# 2    1         3      0
# 3    1         0      0
# 4    0         1      0

# %%
# List of columns to drop
columns_to_drop = ['Name', 'Ticket', 'Cabin']  # Modify this list based on your specific needs

# Drop the unnecessary columns
df_cleaned = df_standardized.drop(columns=columns_to_drop)

# Verify the columns have been dropped
print("\nData after dropping unnecessary columns:")
df_cleaned.describe(include = 'all')
# Out:
# Data after dropping unnecessary columns:
#          PassengerId        Pclass     Sex          Age         SibSp  \
# count   1.017000e+03  1.017000e+03  1017.0  1017.000000  1.017000e+03
# unique           NaN           NaN     2.0          NaN           NaN
# top              NaN           NaN     1.0          NaN           NaN
# freq             NaN           NaN   537.0          NaN           NaN
# mean    1.117865e-16  1.397331e-17     NaN     0.000000  1.379864e-16
# std     1.000492e+00  1.000492e+00     NaN     1.000492  1.000492e+00
# min    -1.729913e+00 -1.177573e+00     NaN    -1.721516 -1.419688e+00
# 25%    -8.643020e-01 -1.177573e+00     NaN    -0.812719 -7.191434e-01
# 50%    -5.588371e-03  4.197053e-02     NaN     0.003230 -1.859853e-02
# 75%     8.669198e-01  1.261514e+00     NaN     0.823116  6.819463e-01
# max     1.749774e+00  1.261514e+00     NaN     2.494657  1.382491e+00
#
#                Parch          Fare  Embarked      Survived
# count   1.017000e+03  1.017000e+03    1017.0  1.017000e+03
# unique           NaN           NaN       4.0           NaN
# top              NaN           NaN       1.0           NaN
# freq             NaN           NaN     413.0           NaN
# mean    4.191993e-17  8.907984e-17       NaN -1.222664e-16
# std     1.000492e+00  1.000492e+00       NaN  1.000492e+00
# min    -1.417000e+00 -1.687867e+00       NaN -9.931405e-01
# 25%    -7.091957e-01 -8.686383e-01       NaN -9.931405e-01
# 50%    -1.391945e-03 -2.046853e-02       NaN -9.931405e-01
# 75%     7.064118e-01  8.261520e-01       NaN  1.006907e+00
# max     1.414216e+00  3.151729e+00       NaN  1.006907e+00

# %%
#Histogram: For Continuous Numerical Data
import matplotlib.pyplot as plt
import seaborn as sns

# List of numerical columns for histogram
numerical_columns = ['Age', 'SibSp', 'Parch', 'Fare']

plt.figure(figsize=(15, 10))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df_cleaned[column], bins=30, kde=True)
    plt.title(f'Histogram of {column}')

plt.tight_layout()
plt.show()

# %%
#Histogram: For Continuous Numerical Data - BEFORE DATA CLEANING
import matplotlib.pyplot as plt
import seaborn as sns

# List of numerical columns for histogram
numerical_columns = ['Age', 'SibSp', 'Parch', 'Fare']

plt.figure(figsize=(15, 10))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df[column], bins=30, kde=True)
    plt.title(f'Histogram of {column}')

plt.tight_layout()
plt.show()

# %%
#Bar Plot: For Categorical Data
plt.figure(figsize=(15, 10))
categorical_columns = ['Pclass', 'Sex', 'Embarked', 'Survived']

for i, column in enumerate(categorical_columns, 1):
    plt.subplot(2, 2, i)
    sns.countplot(x=df_cleaned[column])
    plt.title(f'Bar Plot of {column}')

plt.tight_layout()
plt.show()

# %%
#Bar Plot: For Categorical Data - BEFORE DATA CLEANING
plt.figure(figsize=(15, 10))
categorical_columns = ['Pclass', 'Sex', 'Embarked', 'Survived']

for i, column in enumerate(categorical_columns, 1):
    plt.subplot(2, 2, i)
    sns.countplot(x=df[column])
    plt.title(f'Bar Plot of {column}')

plt.tight_layout()
plt.show()

# %%
#Box Plot: To Visualize Distribution and Detect Outliers
plt.figure(figsize=(15, 10))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x=df_cleaned[column])
    plt.title(f'Box Plot of {column}')

plt.tight_layout()
plt.show()

# %%
#Box Plot: To Visualize Distribution and Detect Outliers - BEFORE DATA CLEANING 
plt.figure(figsize=(15, 10))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x=df[column])
    plt.title(f'Box Plot of {column}')

plt.tight_layout()
plt.show()

# %%
#Pair Plot: To Visualize Pairwise Relationships
import seaborn as sns

# Pair plot for numerical columns
sns.pairplot(df_cleaned[numerical_columns + ['Survived']], hue='Survived')
plt.suptitle('Pair Plot of Numerical Features by Survival', y=1.02)
plt.show()

# %%
#Pair Plot: To Visualize Pairwise Relationships - BEFORE DATA CLEANING
import seaborn as sns

# Pair plot for numerical columns
sns.pairplot(df[numerical_columns + ['Survived']], hue='Survived')
plt.suptitle('Pair Plot of Numerical Features by Survival', y=1.02)
plt.show()

# %%
#Heatmap: To Visualize Correlation Matrix
import seaborn as sns

# Compute correlation matrix
correlation_matrix = df_cleaned[numerical_columns].corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
#Heatmap: To Visualize Correlation Matrix - BEFORE DATA CLEANING 
import seaborn as sns

# Compute correlation matrix
correlation_matrix = df[numerical_columns].corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
#Scatter Plot: Age vs Fare
import matplotlib.pyplot as plt

# Scatter plot: Age vs Fare
plt.figure(figsize=(10, 6))
plt.scatter(df_cleaned['Age'], df_cleaned['Fare'], c=df_cleaned['Survived'], cmap='coolwarm', alpha=0.7, edgecolors='w', s=100)
plt.colorbar(label='Survived')
plt.title('Scatter Plot of Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
#Scatter Plot: Age vs Fare - BEFORE DATA CLEANING
import matplotlib.pyplot as plt

# Scatter plot: Age vs Fare
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['Fare'], c=df['Survived'], cmap='coolwarm', alpha=0.7, edgecolors='w', s=100)
plt.colorbar(label='Survived')
plt.title('Scatter Plot of Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
#Line Plot: Number of Passengers Over Age (Grouped by Class)
# Calculate the number of passengers by Age and Pclass
age_pclass_counts = df_cleaned.groupby(['Age', 'Pclass']).size().reset_index(name='Count')

# Line plot: Number of Passengers by Age and Pclass
plt.figure(figsize=(12, 8))
sns.lineplot(data=age_pclass_counts, x='Age', y='Count', hue='Pclass', marker='o')
plt.title('Number of Passengers by Age and Passenger Class')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.legend(title='Pclass')
plt.grid(True)
plt.show()

# %%
#Line Plot: Number of Passengers Over Age (Grouped by Class) - BEFORE DATA CLEANING
# Calculate the number of passengers by Age and Pclass
age_pclass_counts = df.groupby(['Age', 'Pclass']).size().reset_index(name='Count')

# Line plot: Number of Passengers by Age and Pclass
plt.figure(figsize=(12, 8))
sns.lineplot(data=age_pclass_counts, x='Age', y='Count', hue='Pclass', marker='o')
plt.title('Number of Passengers by Age and Passenger Class')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.legend(title='Pclass')
plt.grid(True)
plt.show()
